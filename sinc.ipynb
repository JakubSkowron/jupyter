# %% [markdown]
# # This is a title
# Short _description_.

# %%
import matplotlib.pyplot as plt
import numpy as np
X = np.linspace(-10,10,1000)
plt.plot(X, np.sinc(X))

# %% [markdown]
# You can enter text in **Markdown**. It allows you to create a documents, which can be pushed to [GutHub](https://github.com), or saved as `PDF` or `HTML`
